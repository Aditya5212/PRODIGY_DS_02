# %% [markdown]
# # Prodigy Infotech Internship
#
# ## Task 2: Perform data cleaning and EDA on dataset. Explore the relationships between variables and identify patterns and trends in the data.
#
# ### Problem Statement:- Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Data Cleaning

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'].fillna(data['Age'].median(),inplace=True)
data.drop('Cabin',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data.dropna(subset=['Embarked'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Performing EDA and Data Visualization

# %%
sns.countplot(x='Survived',palette=['orange','yellow'],edgecolor='black',data=data,hue='Sex')
plt.show()

# %%
data.groupby(['Sex']).Survived.sum()
# Out:
# Sex
# female    231
# male      109
# Name: Survived, dtype: int64

# %%
sns.countplot(x='Survived',hue='Pclass',palette=['orange','yellow','green'],data=data)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.pairplot(data=data, hue="Survived")

# %%
sns.countplot(x='SibSp',data=data)
# Out:
# <AxesSubplot: xlabel='SibSp', ylabel='count'>

# %%
data['Fare'].hist(color='red',bins=30,figsize=(7,5))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Outliers cleaning

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Pclass',y='Age',data=data,palette='winter')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %%
def imp_age(row):
    age = row['Age']
    pclass = row['Pclass']
    if pd.isnull(age):
        if pclass == 1:
            return 32  # Replace with the mean age of Pclass 1
        elif pclass == 2:
            return 28  # Replace with the mean age of Pclass 2
        elif pclass == 3:
            return 25  # Replace with the mean age of Pclass 3
    else:
        return age

# %%
data['Age'] = data[['Age','Pclass']].apply(imp_age,axis=1)

# %% [markdown]
# #### Data is cleaned as per our requirement

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=data,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %% [markdown]
# ## Trends in the data

# %%
sns.lineplot(x='Age', y='Fare', data=data)
plt.title('Time Series Line Plot')
plt.show()

# %%
# Scatter plot with a trendline
sns.regplot(x='SibSp', y='Parch', data=data)
plt.title('Scatter Plot with Trendline')
plt.show()

# %%
sns.regplot(x='Pclass', y='Fare',data=data)
plt.title('Scatter Plot with Trendline')
plt.show()
